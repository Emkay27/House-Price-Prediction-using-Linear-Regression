# %% [markdown]
# ## Overview
#
# Regression analysis is a fundamental concept in the field of machine learning. It falls under supervised learning wherein the algorithm is trained with both input features and output labels. It helps in establishing a relationship among the variables by estimating how one variable affects the other.
#
# #### Linear Regression:
#
# Linear regression finds the linear relationship between the dependent variable and one or more independent variables using a best-fit straight line. Generally, a linear model makes a prediction by simply computing a weighted sum of the input features, plus a constant called the bias term (also called the intercept term). In this technique, the dependent variable is continuous, the independent variable(s) can be continuous or discrete, and the nature of the regression line is linear.
#
# <!-- #### Logistic Regression:
#
# Logistic Regression is a part of the Supervised Learning method of Machine Learning. It is a statistical method for the analysis of a dataset. It has one or more independent variables that determine an outcome. There is one basic difference between Linear Regression and Logistic Regression  which is that Linear Regression's outcome is continuous whereas Logistic Regression's outcome is only limited. -->
#
# ## Approach
#
# We use scikit-learn to implement Linear regression on the housing price dataset to predict the price of the houses in the city based on the income of the residents, age of the houses, number of rooms in the house, number of bedrooms in the house, address and area population in the city.
#
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# ## Dataset
#
# The dataset used here is a house price dataset found from Kaggle, because house price is a continuous variable, then this is a regression problem. The dataset consists of the address of a house, number of houses in the city, Price that a house is sold for, number of rooms in the house, age of the houses in the same city and the income of the residents in the city.
#
# #### Loading the data

# %%
house_pricing = pd.read_csv('HousePricing.csv')

# %% [markdown]
# ##### Shape of  the DataFrame house_pricing

# %%
print(f'The DataFrame house_pricing has {house_pricing.shape[0]} Rows and {house_pricing.shape[1]} Columns.')
# Out:
# The DataFrame house_pricing has 5000 Rows and 7 Columns.

# %% [markdown]
# ##### See first 5 rows

# %%
house_pricing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# ##### See last 5 rows

# %%
house_pricing.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %% [markdown]
# #####  Summary of statistics pertaining to the house_pricing columns

# %%
house_pricing.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ##### Get the information about the house_pricing

# %%
house_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %% [markdown]
# #### Selecting the features to explore

# %%
house_pricing.rename(columns = {'Avg. Area Income' : 'Avg_Area_Income', 
                                'Avg. Area House Age' : 'Avg_Area_House_Age',
                               'Avg. Area Number of Rooms' : 'Avg_Area_Number_of_Rooms',
                               'Avg. Area Number of Bedrooms' : 'Avg_Area_Number_of_Bedrooms',
                               'Area Population' : 'Area_Population'}, inplace = True)
features_explore = house_pricing[['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
                                 'Avg_Area_Number_of_Bedrooms', 'Area_Population', 'Price']]
features_explore.head(10)
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
# 5     80175.754159            4.988408                  6.104512
# 6     64698.463428            6.025336                  8.147760
# 7     78394.339278            6.989780                  6.620478
# 8     59927.660813            5.362126                  6.393121
# 9     81885.927184            4.423672                  8.167688
#
#    Avg_Area_Number_of_Bedrooms  Area_Population         Price
# 0                         4.09     23086.800503  1.059034e+06
# 1                         3.09     40173.072174  1.505891e+06
# 2                         5.13     36882.159400  1.058988e+06
# ...

# %% [markdown]
# #### Plot each of the features

# %%
feature_plots = features_explore.hist(color = 'red')
plt.subplots_adjust(left=None, bottom=None, right=2.5, top=2, wspace=None, hspace=0.4)
plt.show()

# %% [markdown]
# #### Correlation Matrix Plot
#
# Since the dataset has many columns, we use the correlation matrix as a heatmap to quickly get a visualization of the correlations among columns, on the heatmap below, we see that green means positive and red means negative, so the stronger the color the larger the correlation magnitude. The main diagonal shows the strongest correlated pairs, we can see that Avg_Area_Income, Avg_Area_House_Age and Area_population are respectively the three most correlated variables with the Price.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(house_pricing.corr(), annot = True, cmap = 'RdYlGn', linewidth = 1)
plt.show()

# %% [markdown]
# #### Plot each of these features vs the Price feature
#
# We do this because we want to see their relation.

# %%
plt.figure(figsize=(10,8))
plt.scatter(features_explore.Avg_Area_Income, features_explore.Price, color = 'green')
plt.title('Avg_Area_Income vs Price', fontsize = 14)
plt.xlabel('Avg_Area_Income', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(features_explore.Avg_Area_House_Age, features_explore.Price, color = 'blue')
plt.title('Avg_Area_House_Age vs Price', fontsize = 14)
plt.xlabel('Avg_Area_House_Age', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(features_explore.Avg_Area_Number_of_Rooms, features_explore.Price, color = 'red')
plt.title('Avg_Area_Number_of_Rooms vs Price', fontsize = 14)
plt.xlabel('Avg_Area_Number_of_Rooms', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(features_explore.Avg_Area_Number_of_Bedrooms, features_explore.Price, color = 'cyan')
plt.title('Avg_Area_Number_of_Bedrooms vs Price', fontsize = 14)
plt.xlabel('Avg_Area_Number_of_Bedrooms', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(features_explore.Area_Population, features_explore.Price, color = 'maroon')
plt.title('Area_Population vs Price', fontsize = 14)
plt.xlabel('Area_Population', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
plt.show()

# %% [markdown]
# #### Describing the dependent and Independent variables
#
# Here X_dep represents the dependent variables, Y_indep represents the independent variable.

# %%
X_dep = house_pricing[['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
                      'Area_Population']]
Y_indep = house_pricing['Price']

# %% [markdown]
# #### Dependent variables

# %%
X_dep.head()
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Area_Population
# 0     23086.800503
# 1     40173.072174
# 2     36882.159400
# 3     34310.242831
# 4     26354.109472

# %% [markdown]
# #### Independent variable

# %%
Y_indep.head()
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# Name: Price, dtype: float64

# %% [markdown]
# #### Creating a train and test dataset
#
#
# We split the dataset into training and testing sets respectively and then train with the training set, in doing so we can have an accurate evaluation of the out-of-sample accuracy because the testing set is not part of the dataset that we used to train the model. Here 80% of the dataset is for training and the remaining 20% is for testing, we use 42 for the random state.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_dep, Y_indep, test_size = 0.2, random_state = 42)

# %% [markdown]
# #### Train dataset

# %%
x_train.head()
# Out:
#       Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 4227     66547.016454            5.846095                  6.847298
# 4676     53722.008599            6.401391                  7.787764
# 800      64838.492899            6.437157                  8.699544
# 3671     67097.092120            6.086754                  7.211963
# 4193     75245.465436            8.167820                  7.420100
#
#       Area_Population
# 4227     27850.822901
# 4676     47649.224665
# 800      32921.010068
# 3671     27191.506877
# 4193     37410.669928

# %%
y_train.head()
# Out:
# 4227    1.094880e+06
# 4676    1.300389e+06
# 800     1.382172e+06
# 3671    1.027428e+06
# 4193    1.562887e+06
# Name: Price, dtype: float64

# %% [markdown]
# #### Test dataset

# %%
x_test.head()
# Out:
#       Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 1501     61907.593345            7.017838                  6.440256
# 2586     57160.202243            6.893260                  6.921532
# 2653     70190.796445            6.745054                  6.662567
# 1055     69316.796889            6.300409                  7.873576
# 705      72991.481649            3.412866                  6.494081
#
#       Area_Population
# 1501     43828.947207
# 2586     43467.147035
# 2653     29215.136112
# 1055     24448.211461
# 705      50626.495426

# %%
y_test.head()
# Out:
# 1501    1.339096e+06
# 2586    1.251794e+06
# 2653    1.340095e+06
# 1055    1.431508e+06
# 705     1.042374e+06
# Name: Price, dtype: float64

# %% [markdown]
# #### Train data distribution

# %%
sns.pairplot(x_train)
sns.set_palette('viridis')
plt.show()

# %% [markdown]
# #### Test data distribution

# %%
sns.pairplot(x_test)
sns.set_palette('afmhot')
plt.show()
